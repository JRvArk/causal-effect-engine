# %% [markdown]
# # 03 — CATE Models
#
# Meta-learners (S/T/X/DR) vs. causal forests on IHDP. Evaluate with PEHE against known true CATEs. This is the genuinely ML layer.

# %%
import pandas as pd
import sys
sys.path.insert(0, '..')

from src.estimators.cate import s_learner, t_learner, x_learner, dr_learner, causal_forest
from src.evaluation.pehe import pehe, policy_risk

# %% [markdown]
# ## 1. Load IHDP

# %%
# TODO

# %% [markdown]
# ## 2. Meta-learners

# %%
# TODO: fit S/T/X/DR learners, compute PEHE for each

# %% [markdown]
# ## 3. Causal forest

# %%
# TODO

# %% [markdown]
# ## 4. PEHE comparison table

# %%
# TODO

# %% [markdown]
# ## 5. CATE distribution plot

# %%
# TODO: scatter estimated vs. true CATE
