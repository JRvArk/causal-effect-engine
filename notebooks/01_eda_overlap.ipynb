# %% [markdown]
# # 01 — EDA & Propensity Overlap
#
# Load LaLonde into DuckDB, explore outcome distributions, and check propensity-score overlap between treated and control. Poor overlap is the silent killer — confront it first.

# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.insert(0, '..')

from src.ingestion.load_datasets import get_connection, load_lalonde
from src.identification.checks import check_overlap, balance_diagnostics

# %% [markdown]
# ## 1. Load LaLonde

# %%
# TODO: load_lalonde(db)

# %% [markdown]
# ## 2. Outcome distributions by treatment status

# %%
# TODO: plot re78 by treat

# %% [markdown]
# ## 3. Propensity score estimation & overlap

# %%
# TODO: fit propensity model, plot overlap histogram, flag violations

# %% [markdown]
# ## 4. Balance diagnostics (SMDs)

# %%
# TODO: balance_diagnostics(df, 'treat', covariates)
