# %% [markdown]
# # 04 — Validation: Refutation, Sensitivity & Uplift
#
# Stress-test the estimates. Placebo tests, random common cause, subset stability, E-values, and the Criteo uplift / Qini demo.

# %%
import pandas as pd
import sys
sys.path.insert(0, '..')

from src.evaluation.refutation import placebo_treatment, random_common_cause, subset_stability
from src.evaluation.sensitivity import e_value, rv_sens
from src.evaluation.uplift import qini_curve, auuc, uplift_by_decile

# %% [markdown]
# ## 1. Refutation — placebo treatment

# %%
# TODO: expected result ~0; failing this is a red flag

# %% [markdown]
# ## 2. Refutation — random common cause

# %%
# TODO: estimate should be stable

# %% [markdown]
# ## 3. Subset stability

# %%
# TODO

# %% [markdown]
# ## 4. Sensitivity — E-value

# %%
# TODO: 'our effect survives unless a confounder has RR > X'

# %% [markdown]
# ## 5. Criteo uplift — Qini curve & AUUC

# %%
# TODO

# %% [markdown]
# ## 6. Uplift by decile

# %%
# TODO
