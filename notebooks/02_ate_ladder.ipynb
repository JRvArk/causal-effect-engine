# %% [markdown]
# # 02 — ATE Ladder
#
# Naive difference → IPW → AIPW → Double ML, side by side on LaLonde. The comparison is the point: show how each rung corrects the failure of the one below it.

# %%
import pandas as pd
import sys
sys.path.insert(0, '..')

from src.estimators.ate import naive_difference, ipw, aipw, double_ml
from src.evaluation.benchmark import compare_to_experimental, LALONDE_EXPERIMENTAL_ATE

# %% [markdown]
# ## 1. Naive baseline

# %%
# TODO

# %% [markdown]
# ## 2. IPW

# %%
# TODO

# %% [markdown]
# ## 3. AIPW (doubly robust)

# %%
# TODO

# %% [markdown]
# ## 4. Double / Debiased ML

# %%
# TODO

# %% [markdown]
# ## 5. Comparison vs. experimental benchmark

# %%
# TODO: plot all estimates with CIs against LALONDE_EXPERIMENTAL_ATE
